# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxxOlivo/NFLAnalysis/blob/main/NFL_Combine_Draft_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import correct Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import google
from google.colab import drive
drive.mount('/content/drive')

#importing pandas, numpy, matplotlib.pyplot, seaborn, and google
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Import Datasets from Google drive

# %%
df1 = pd.read_excel('/content/drive/MyDrive/Personal Coding Projects/2025 NFL Combine Dataset.xlsx') #Uploading both datasets, one being an excel file and other a csv file
df2 = pd.read_csv('/content/drive/MyDrive/Personal Coding Projects/nfl_combine_2010_to_2023.csv')

# %% [markdown]
# Statement: Does 40 yard dash speed (collected via combine) relate to a wide receiver getting drafted and a specific round? excludes receivers who did not participate in the 40 yard dash at the Combine. Predictions of what Receivers in the 2025 NFL draft get drafted and what round based off the data collected

# %% [markdown]
# # Dataset 1: NFL Combine 2025

# %% [markdown]
# ## Data Information of this dataset

# %%
df1.head()
# Out:
#                        Name Position   School   Height  Weight Hand Size  \
# 0                  BJ Adams       DB      UCF      6-2     182      8.75
# 1               Cam Jackson       DL  Florida  6-6 2/8     328       9.5
# 2               Gunnar Helm       TE    Texas     6-5      241     9.875
# 3              Zy Alexander       DB      LSU  6-1 3/8     187      9.25
# 4  Brandon Crenshaw-Dickson       OL  Florida  6-7 1/4     316      10.5
#
#   Arm Length Wingspan 40 Yard Dash  Bench Press  Vertical Jump  Broad Jump  \
# 0      31.75      NaN         4.53          NaN           32.5    9.750000
# 1     34.125   81.875         5.17          NaN           24.5    7.750000
# 2      32.75     79.5         4.84          NaN           30.0         NaN
# 3         31     77.5         4.56          NaN           31.5    9.666667
# 4         34     83.5         5.33          NaN           24.5    8.000000
#
#    3-Cone Drill  20 Yard Shuttle  Athleticism Score Height (Numeric)  \
# ...

# %%
df1.isnull().sum()
# Out:
# Name                    0
# Position                0
# School                  0
# Height                  0
# Weight                  0
# Hand Size               1
# Arm Length              1
# Wingspan               79
# 40 Yard Dash           54
# Bench Press           261
# Vertical Jump         118
# Broad Jump            128
# 3-Cone Drill          252
# 20 Yard Shuttle       245
# Athleticism Score       0
# Height (Numeric)        0
# Hand (Numeric)          1
# Arm (Numeric)          49
# Wingspan (Numeric)      1
# dtype: int64

# %% [markdown]
# No player is missing but numerous activities from the NFL combine are

# %% [markdown]
# ## Wide Receivers 40 Yard Dash at the 2025 combine

# %%
WR2 = df1[(df1['Position'] == 'WR') ] #Make a dataframe for the WR position for this dataset
WR2.head()
# Out:
#                 Name Position      School    Height  Weight Hand Size  \
# 5         Josh Kelly       WR  Texas Tech   6-0 5/8     186      10.5
# 12    Theo Wease Jr.       WR    Missouri       6-3     200     9.625
# 15   Ricky White III       WR        UNLV   6-1 1/8     184      9.25
# 17  Konata Mumpfield       WR  Pittsburgh  5-11 3/8     186       8.5
# 26       Tez Johnson       WR      Oregon   5-9 7/8     154         9
#
#    Arm Length Wingspan 40 Yard Dash  Bench Press  Vertical Jump  Broad Jump  \
# 5      30.875      NaN          4.7          NaN           33.0   10.083333
# 12     32.125      NaN         4.56          NaN           31.0    9.750000
# 15      31.75      NaN         4.61          NaN           36.0   10.250000
# 17     29.375      NaN         4.59          NaN           36.0   10.333333
# 26     29.375      NaN         4.51          NaN           37.0   10.916667
#
#     3-Cone Drill  20 Yard Shuttle  Athleticism Score Height (Numeric)  \
# ...

# %% [markdown]
# How many WRs have ran the 40 between 4.2-4.4 in 2025?

# %%
#WR2['40 Yard Dash'] = pd.to_numeric(WR2['40 Yard Dash'], errors='coerce')

FastWR1 = WR2[(WR2['40 Yard Dash'] >= 4.2) & (WR2['40 Yard Dash'] <= 4.4)].count()
FastWR1
# Out:
# Name                  12
# Position              12
# School                12
# Height                12
# Weight                12
# Hand Size             12
# Arm Length            12
# Wingspan               0
# 40 Yard Dash          12
# Bench Press            2
# Vertical Jump         10
# Broad Jump            10
# 3-Cone Drill           4
# 20 Yard Shuttle        5
# Athleticism Score     12
# Height (Numeric)      12
# Hand (Numeric)        12
# Arm (Numeric)          0
# Wingspan (Numeric)    12
# dtype: int64

# %% [markdown]
# 12 Receivers ran the 40 at the NFL combine between 4.2 and 4.4

# %% [markdown]
# How many WRs have ran the 40 between 4.5 - 4.6 in 2025?

# %%
MediumWR1  = WR2[(WR2['40 Yard Dash'] >= 4.5) & (WR2['40 Yard Dash'] <= 4.6)].count()
#MediumWR.sort_values(by='40 Yard Dash', ascending=True)
MediumWR1
# Out:
# Name                  11
# Position              11
# School                11
# Height                11
# Weight                11
# Hand Size             11
# Arm Length            11
# Wingspan               0
# 40 Yard Dash          11
# Bench Press            2
# Vertical Jump         11
# Broad Jump            11
# 3-Cone Drill           3
# 20 Yard Shuttle        3
# Athleticism Score     11
# Height (Numeric)      11
# Hand (Numeric)        11
# Arm (Numeric)          0
# Wingspan (Numeric)    11
# dtype: int64

# %% [markdown]
# 11 Receivers ran the 40 yard dash at the NFL Combine between 4.5 and 4.6

# %% [markdown]
# How many WRs have ran the 40 at 4.7 or higher in 2025?

# %%
BelowAvgWR = WR2[(WR2['40 Yard Dash'] >= 4.7)  & (WR2['Position'] == 'WR')].count()
BelowAvgWR
# Out:
# Name                  1
# Position              1
# School                1
# Height                1
# Weight                1
# Hand Size             1
# Arm Length            1
# Wingspan              0
# 40 Yard Dash          1
# Bench Press           0
# Vertical Jump         1
# Broad Jump            1
# 3-Cone Drill          1
# 20 Yard Shuttle       0
# Athleticism Score     1
# Height (Numeric)      1
# Hand (Numeric)        1
# Arm (Numeric)         0
# Wingspan (Numeric)    1
# dtype: int64

# %% [markdown]
# 1 receiver ran the 40 yard dash at the NFL combine at 4.7

# %%
sns.histplot(data=WR2, x='40 Yard Dash', bins = 3, kde = True)
plt.title('Wide Receiver 40 Yard Dash by Frequency')
plt.xlabel('40 Yard Dash')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(data=WR2, x='40 Yard Dash')
plt.title('Wide Receiver 40 Yard Dash by Count')
plt.xlabel('40 Yard Dash')
plt.ylabel('Count')
plt.show()

# %%
sns.lineplot(data=WR2, x='40 Yard Dash', y='Athleticism Score', color = 'grey')
plt.title('Wide Receiver 40 Yard Dash by Athleticism Score', color = 'green')
plt.xlabel('40 Yard Dash')
plt.ylabel('Athleticism Score')
plt.show()

# %%
sns.scatterplot(data=WR2, x='40 Yard Dash', y='Athleticism Score', hue='Athleticism Score', palette='viridis')
plt.title('Wide Receiver 40 Yard Dash by Athleticism Score')
plt.xlabel('40 Yard Dash')
plt.ylabel('Athleticism Score')
plt.show()

# %%
# Run both of these once for the graph: WR2['40 Yard Dash'] = pd.to_numeric(WR2['40 Yard Dash'], errors='coerce')
#WR2['Athleticism Score'] = pd.to_numeric(WR2['Athleticism Score'], errors='coerce')

# Drop rows with NaN values in '40 Yard Dash' and 'Athleticism Score'
WR2 = WR2.dropna(subset=['40 Yard Dash', 'Athleticism Score'])

sns.scatterplot(data=WR2, x='40 Yard Dash', y='Athleticism Score', hue='Athleticism Score', palette='viridis')


x = WR2['40 Yard Dash']
y = WR2['Athleticism Score']
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
plt.plot(x, p(x), color='red', linestyle='--', label='Trendline')


plt.title('40 Yard Dash vs Athleticism Score')
plt.legend()
plt.grid(True)
plt.show()

# %%
sns.boxplot(data=WR2, x='Athleticism Score')
plt.title('Wide Receiver 40 Yard Dash by Round')
plt.xlabel('Athleticism Score')
plt.ylabel('Count')
plt.show()

# %%
#Mean, Maximum, Minimum
Mean = WR2['40 Yard Dash'].mean()
Max = WR2['40 Yard Dash'].max()
Min = WR2['40 Yard Dash'].min()
print('The max of the 2025 draft class is',Max)
print('The min of the 2025 draft class is',Min)
print('The mean of the 2025 draft class is',Mean)
# Out:
# The max of the 2025 draft class is 4.7
# The min of the 2025 draft class is 4.29
# The mean of the 2025 draft class is 4.463333333333334

# %%
#Athleticism score and player from 60 - 69, 70-79, 80-89, 90-99
WR2['Athleticism Score'] = pd.to_numeric(WR2['Athleticism Score'], errors='coerce')
ninety_percentile = WR2[(WR2['Athleticism Score'] >= 90)  & (WR2['Position'] == 'WR')].count()
eighty_percentile = WR2[(WR2['Athleticism Score'] >= 80) & (WR2['Athleticism Score'] < 90) & (WR2['Position'] == 'WR')].count()
seventy_percentile = WR2[(WR2['Athleticism Score'] >= 70) & (WR2['Athleticism Score'] < 80) & (WR2['Position'] == 'WR')].count()
sixty_percentile = WR2[(WR2['Athleticism Score'] >= 60) & (WR2['Athleticism Score'] < 70) & (WR2['Position'] == 'WR')].count()
print('The elite of Draft Prospects have a rating between  90-99, there are:',ninety_percentile, 'players who are in this rating')
print('The great Draft Prospects have a rating between  80-89, there are:',eighty_percentile, 'players who are in this rating')
print('The average Draft Prospects have a rating between  70-79, there are:',seventy_percentile, 'players who are in this rating')
print('The below average Draft Prospects have a rating between  60-69, there are:',sixty_percentile, 'players who are in this rating')
# Out:
# The elite of Draft Prospects have a rating between  90-99, there are: Name                  6
# Position              6
# School                6
# Height                6
# Weight                6
# Hand Size             6
# Arm Length            6
# Wingspan              0
# 40 Yard Dash          6
# Bench Press           3
# Vertical Jump         6
# Broad Jump            5
# 3-Cone Drill          3
# 20 Yard Shuttle       3
# Athleticism Score     6
# Height (Numeric)      6
# Hand (Numeric)        6
# Arm (Numeric)         0
# Wingspan (Numeric)    6
# dtype: int64 players who are in this rating
# The great Draft Prospects have a rating between  80-89, there are: Name                  11
# Position              11
# School                11
# Height                11
# Weight                11
# Hand Size             11
# Arm Length            11
# Wingspan               0
# 40 Yard Dash          10
# Bench Press            1
# Vertical Jump          7
# ...

# %%
#Print name of players in each section
ninety_percentile_name = WR2['Name']
eighty_percentile_name = WR2['Name']
seventy_percentile_name = WR2['Name']
sixty_percentile_name = WR2['Name']
#Player has 4.2 to 4.4 40 yard dash and 85 to 90 rating
elite_prospect = WR2[(WR2['40 Yard Dash'] >= 4.2) & (WR2['40 Yard Dash'] <= 4.4) & (WR2['Athleticism Score'] >=85) ]
print(elite_prospect)
#Player has 4.5 to 4.6 40 yard dash and 80 rating
great_prospect = WR2[(WR2['40 Yard Dash'] >= 4.5) & (WR2['40 Yard Dash'] <= 4.6) & (WR2['Athleticism Score'] >=75) & (WR2['Athleticism Score'] <85) ]
print(great_prospect)
# Out:
#                     Name Position         School    Height  Weight Hand Size  \
# 170         Chimere Dike       WR        Florida   6-0 5/8     196     9.125
# 171       Matthew Golden       WR          Texas      5-11     191       9.5
# 176  Dont'e Thornton Jr.       WR      Tennessee   6-4 5/8     205     9.625
# 181          Jaylin Lane       WR  Virginia Tech   5-9 3/4     191     9.875
# 184          Jaylin Noel       WR     Iowa State  5-10 1/4     194      8.75
# 193         Isaiah Neyor       WR       Nebraska   6-4 1/4     218       9.5
#
#     Arm Length Wingspan  40 Yard Dash  Bench Press  Vertical Jump  Broad Jump  \
# 170     32.125      NaN          4.34          NaN           38.5   10.666667
# 171     30.625      NaN          4.29          NaN            NaN         NaN
# 176     32.125      NaN          4.30          NaN           33.0   10.500000
# 181      31.75      NaN          4.34         14.0           40.0   11.000000
# ...

# %%
sns.histplot(data=WR2, x='Athleticism Score', bins = 4, kde = True, color='brown')
plt.title('Wide Receiver Athleticism Score by Frequency')
plt.xlabel('Athleticism Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Dataset 2: NFL Combine/Draft 2010-2023

# %%
df2.head()
#Drop the drafted column
df2 = df2.drop('Drafted', axis=1)
df2.head()
# Out:
#    Year             Player Pos         School Height  Weight  40yd  Vertical  \
# 0  2010     Seyi Ajirotutu  WR   Fresno State    6-3   204.0  4.60      36.0
# 1  2010         Rahim Alem  DE            LSU    6-3   251.0  4.75      30.5
# 2  2010  Charles Alexander  DT            LSU    6-4   300.0  5.40       NaN
# 3  2010  Danario Alexander  WR       Missouri    6-5   215.0  4.62       NaN
# 4  2010         Nate Allen   S  South Florida    6-0   207.0  4.50       NaN
#
#    Bench  Broad Jump  3Cone  Shuttle  Round  Pick
# 0   14.0       115.0   7.22     4.39    NaN   NaN
# 1    NaN       106.0   7.54     4.80    NaN   NaN
# 2    NaN         NaN    NaN      NaN    NaN   NaN
# 3    NaN         NaN    NaN      NaN    NaN   NaN
# 4   16.0         NaN    NaN      NaN    2.0  37.0

# %%
#Code for changing the null of round to 0 which would correlate to undrafted
df2['Round'] = df2['Round'].fillna(0)

#Change pick 0.0 to 257.0
df2['Pick'] = df2['Pick'].fillna(0)
df2.head()
# Out:
#    Year             Player Pos         School Height  Weight  40yd  Vertical  \
# 0  2010     Seyi Ajirotutu  WR   Fresno State    6-3   204.0  4.60      36.0
# 1  2010         Rahim Alem  DE            LSU    6-3   251.0  4.75      30.5
# 2  2010  Charles Alexander  DT            LSU    6-4   300.0  5.40       NaN
# 3  2010  Danario Alexander  WR       Missouri    6-5   215.0  4.62       NaN
# 4  2010         Nate Allen   S  South Florida    6-0   207.0  4.50       NaN
#
#    Bench  Broad Jump  3Cone  Shuttle  Round  Pick
# 0   14.0       115.0   7.22     4.39    0.0   0.0
# 1    NaN       106.0   7.54     4.80    0.0   0.0
# 2    NaN         NaN    NaN      NaN    0.0   0.0
# 3    NaN         NaN    NaN      NaN    0.0   0.0
# 4   16.0         NaN    NaN      NaN    2.0  37.0

# %%
df2.isnull().sum()
# Out:
# Year             0
# Player           0
# Pos              0
# School           0
# Height          29
# Weight          24
# 40yd           547
# Vertical      1010
# Bench         1575
# Broad Jump    1070
# 3Cone         1947
# Shuttle       1832
# Round            0
# Pick             0
# dtype: int64

# %% [markdown]
# No players have been missing from this dataset

# %%
#Change the column names to match DataSet 1
df2.rename(columns={'40yd': '40 Yard Dash'}, inplace=True)
df2.rename(columns={'Vertical': 'Vertical Jump'}, inplace=True)
df2.rename(columns={'Bench': 'Bench Press'}, inplace=True)
df2.rename(columns={'Broad Jump': 'Broad Jump'}, inplace=True)
df2.rename(columns={'3Cone': '3 Cone Drill'}, inplace=True)
df2.rename(columns={'Shuttle': 'Shuttle'}, inplace=True)
df2.rename(columns={'Pos': 'Position'},inplace=True)
df2.rename(columns={'Player':'Name'},inplace=True)
df2.rename(columns={'Ht':'Height'},inplace=True)
df2.rename(columns={'Wt':'Weight'},inplace=True)

# %% [markdown]
# ## Wide Receiver 40 Yard Dash at the combine

# %%
df2['40 Yard Dash'] = pd.to_numeric(df2['40 Yard Dash'], errors='coerce')

FastWR = df2[(df2['40 Yard Dash'] >= 4.2) & (df2['40 Yard Dash'] <= 4.4) & (df2['Position'] == 'WR')].count()
FastWR
# Out:
# Year             91
# Name             91
# Position         91
# School           91
# Height           90
# Weight           90
# 40 Yard Dash     91
# Vertical Jump    85
# Bench Press      57
# Broad Jump       86
# 3 Cone Drill     57
# Shuttle          58
# Round            91
# Pick             91
# dtype: int64

# %% [markdown]
# 91 receivers had a 40 yard dash time between 4.2 and 4.4 between 2010 and 2023

# %%
df2['40 Yard Dash'] = pd.to_numeric(df2['40 Yard Dash'], errors='coerce')

MediumWR = df2[(df2['40 Yard Dash'] >= 4.5) & (df2['40 Yard Dash'] <= 4.6) & (df2['Position'] == 'WR')].count()
MediumWR
# Out:
# Year             250
# Name             250
# Position         250
# School           250
# Height           248
# Weight           248
# 40 Yard Dash     250
# Vertical Jump    231
# Bench Press      187
# Broad Jump       226
# 3 Cone Drill     166
# Shuttle          175
# Round            250
# Pick             250
# dtype: int64

# %% [markdown]
# 11 players have ran the 40 yard dash between 4.5 and 4.6 between 2010-2023

# %%
df2['40 Yard Dash'] = pd.to_numeric(df2['40 Yard Dash'], errors='coerce')

BelowAVGWR = df2[(df2['40 Yard Dash'] >= 4.7) & (df2['Position'] == 'WR')].count()
BelowAVGWR
# Out:
# Year             17
# Name             17
# Position         17
# School           17
# Height           17
# Weight           17
# 40 Yard Dash     17
# Vertical Jump    15
# Bench Press      12
# Broad Jump       14
# 3 Cone Drill     10
# Shuttle          10
# Round            17
# Pick             17
# dtype: int64

# %% [markdown]
# 17 receivers have run the 40 at 4.7 or more between 2010-2023

# %%
#Creation of data frame for dataset 2 for Receivers

WR = df2[(df2['Position'] == 'WR') ]
WR.head()
# Out:
#     Year               Name Position         School Height  Weight  \
# 0   2010     Seyi Ajirotutu       WR   Fresno State    6-3   204.0
# 3   2010  Danario Alexander       WR       Missouri    6-5   215.0
# 10  2010       Alric Arnett       WR  West Virginia    6-2   188.0
# 14  2010      Brandon Banks       WR   Kansas State    5-7   149.0
# 18  2010         Chris Bell       WR  Norfolk State    6-2   211.0
#
#     40 Yard Dash  Vertical Jump  Bench Press  Broad Jump  3 Cone Drill  \
# 0           4.60           36.0         14.0       115.0          7.22
# 3           4.62            NaN          NaN         NaN           NaN
# 10          4.52           40.0          NaN       122.0          7.03
# 14          4.37           31.0          NaN       113.0          6.88
# 18          4.50           35.0         15.0       117.0          6.76
#
#     Shuttle  Round  Pick
# 0      4.39    0.0   0.0
# 3       NaN    0.0   0.0
# 10     4.43    0.0   0.0
# 14     4.29    0.0   0.0
# ...

# %%
sns.histplot(data=WR, x='40 Yard Dash', bins = 3, kde = True)
plt.title('Wide Receiver 40 Yard Dash by Frequency')
plt.xlabel('40 Yard Dash')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(data=WR, x='40 Yard Dash', bins = 3, color = 'brown')
plt.title('Wide Receiver 40 Yard Dash by Frequency')
plt.xlabel('40 Yard Dash')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(data=WR, x='Round', y='40 Yard Dash')
plt.title('Wide Receiver 40 Yard Dash by Round')
plt.xlabel('Round')
plt.ylabel('40 Yard Dash')
plt.show()

# %%
sns.lineplot(data=WR, x='Round', y='40 Yard Dash')
plt.title('Wide Receiver 40 Yard Dash by Round')
plt.xlabel('Round')
plt.ylabel('40 Yard Dash')
plt.show()

# %%
sns.scatterplot(data=WR, x='Pick', y='40 Yard Dash', color = 'black')
plt.title('Wide Receiver 40 Yard Dash by Pick')
plt.xlabel('Pick')
plt.ylabel('40 Yard Dash')
plt.show()

# %%
sns.scatterplot(data=WR, x='Round', y='40 Yard Dash', color = 'grey')
plt.title('Wide Receiver 40 Yard Dash by Round')
plt.xlabel('Round')
plt.ylabel('40 Yard Dash')
plt.show()

# %%
if '40 Yard Dash' in WR.columns:
  print('The slowest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:', WR['40 Yard Dash'].max())
# Out:
# The slowest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 4.85

# %%
if '40 Yard Dash' in WR.columns:
  print('The fastest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:',WR['40 Yard Dash'].min())
# Out:
# The fastest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 4.22

# %%
WRmean = WR['40 Yard Dash'].mean()
print('The average 40 yard dash ran by a receiver at the NFL Combine since 2010 (exlcuding 2014) was:',round(WRmean,2))
# Out:
# The average 40 yard dash ran by a receiver at the NFL Combine since 2010 (exlcuding 2014) was: 4.51

# %% [markdown]
# # Creation of Dataset 3: NFL Combine 2010-2025 (excluding 2024)

# %%
#Trying to combine both dataframes but dealt with complications as both data sets have different values for 6-7 columns

df3 = pd.concat([df1, df2], axis=0)


df3['Year'] = df3['Year'].fillna(2025)

df3.tail()
# Out:
#                Name Position           School Height  Weight Hand Size  \
# 4736    Luke Wypler        C         Ohio St.    6-3   303.0       NaN
# 4737    Bryce Young       QB          Alabama   5-10   204.0       NaN
# 4738    Byron Young       DT          Alabama    6-3   294.0       NaN
# 4739    Byron Young     EDGE        Tennessee    6-2   250.0       NaN
# 4740  Cameron Young       DT  Mississippi St.    6-3   304.0       NaN
#
#      Arm Length Wingspan 40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 4736        NaN      NaN         5.14          NaN  ...                NaN
# 4737        NaN      NaN          NaN          NaN  ...                NaN
# 4738        NaN      NaN          NaN         24.0  ...                NaN
# 4739        NaN      NaN         4.43         22.0  ...                NaN
# 4740        NaN      NaN          5.1          NaN  ...                NaN
#
#       Height (Numeric)  Hand (Numeric)  Arm (Numeric)  Wingspan (Numeric)  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5066 entries, 0 to 4740
# Data columns (total 24 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                5066 non-null   object
#  1   Position            5066 non-null   object
#  2   School              5066 non-null   object
#  3   Height              5037 non-null   object
#  4   Weight              5042 non-null   float64
#  5   Hand Size           324 non-null    object
#  6   Arm Length          324 non-null    object
#  7   Wingspan            246 non-null    object
#  8   40 Yard Dash        4465 non-null   object
#  9   Bench Press         3230 non-null   float64
#  10  Vertical Jump       3938 non-null   float64
#  11  Broad Jump          3868 non-null   float64
#  12  3-Cone Drill        73 non-null     float64
#  13  20 Yard Shuttle     80 non-null     float64
#  14  Athleticism Score   325 non-null    float64
# ...

# %%
df3.describe().T
# Out:
#                     count         mean        std      min      25%      50%  \
# Weight             5042.0   241.855415  45.631663   144.00   204.00   231.00
# Bench Press        3230.0    20.210836   6.417242     2.00    15.00    20.00
# Vertical Jump      3938.0    32.981412   4.188888    17.50    30.00    33.00
# Broad Jump         3868.0   110.465443  24.973820     7.75   109.00   116.00
# 3-Cone Drill         73.0     7.283699   0.371840     6.65     7.01     7.22
# 20 Yard Shuttle      80.0     4.445500   0.233563     4.03     4.27     4.40
# Athleticism Score   325.0    74.520000  10.268482    19.00    68.00    74.00
# Year               5066.0  2017.163837   4.403893  2010.00  2013.00  2017.00
# 3 Cone Drill       2794.0     7.251933   0.405234     6.28     6.96     7.15
# Shuttle            2909.0     4.415895   0.262608     3.81     4.22     4.37
# Round              4741.0     2.436406   2.397787     0.00     0.00     2.00
# ...

# %% [markdown]
# ## Wide Receiver breakdown from Dataset 3

# %%
#Create a dataframe that is specific to Wide Receivers
WR1 = df3[(df3['Position'] == 'WR') ]
WR1.tail()
# Out:
#                    Name Position         School Height  Weight Hand Size  \
# 4705         Tre Tucker       WR     Cincinnati    5-9   182.0       NaN
# 4719  Parker Washington       WR       Penn St.   5-10   204.0       NaN
# 4720        Jalen Wayne       WR  South Alabama    6-2   210.0       NaN
# 4725   Dontayvion Wicks       WR       Virginia    6-1   206.0       NaN
# 4729     Michael Wilson       WR       Stanford    6-2   213.0       NaN
#
#      Arm Length Wingspan 40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 4705        NaN      NaN          4.4          NaN  ...                NaN
# 4719        NaN      NaN          NaN         16.0  ...                NaN
# 4720        NaN      NaN         4.51          NaN  ...                NaN
# 4725        NaN      NaN         4.62          NaN  ...                NaN
# 4729        NaN      NaN         4.58         23.0  ...                NaN
#
# ...

# %%
FastWR = WR1[(WR1['40 Yard Dash'] >= 4.2) & (WR1['40 Yard Dash'] <= 4.4)]
FastWR.head()
# Out:
#                       Name Position       School    Height  Weight Hand Size  \
# 83          Dominic Lovett       WR      Georgia      5-10   185.0      9.25
# 104          Kyle Williams       WR          WSU  5-10 5/8   190.0      8.75
# 118            Isaiah Bond       WR        Texas  5-10 5/8   180.0       8.5
# 131  KeAndre Lambert-Smith       WR       Auburn   6-0 5/8   186.0      10.5
# 137         Jordan Watkins       WR  Mississippi  5-11 1/4   196.0     9.125
#
#     Arm Length Wingspan 40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 83      31.375      NaN          4.4          NaN  ...               73.0
# 104     30.125      NaN          4.4          NaN  ...               76.0
# 118       30.5      NaN         4.39          NaN  ...               78.0
# 131     30.875      NaN         4.37          NaN  ...               80.0
# 137     29.375      NaN         4.37          NaN  ...               81.0
#
# ...

# %%
MediumWR = WR1[(WR1['40 Yard Dash'] >= 4.5) & (WR1['40 Yard Dash'] <= 4.6)]
MediumWR.head()
# Out:
#                 Name Position      School    Height  Weight Hand Size  \
# 12    Theo Wease Jr.       WR    Missouri       6-3   200.0     9.625
# 17  Konata Mumpfield       WR  Pittsburgh  5-11 3/8   186.0       8.5
# 26       Tez Johnson       WR      Oregon   5-9 7/8   154.0         9
# 29   Traeshon Holden       WR      Oregon   6-2 1/8   205.0     9.875
# 30       Kobe Hudson       WR         UCF   6-0 3/4   193.0         9
#
#    Arm Length Wingspan 40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 12     32.125      NaN         4.56          NaN  ...               59.0
# 17     29.375      NaN         4.59          NaN  ...               62.0
# 26     29.375      NaN         4.51          NaN  ...               64.0
# 29     31.625      NaN         4.57          NaN  ...               65.0
# 30     30.625      NaN         4.57          NaN  ...               65.0
#
#     Height (Numeric)  Hand (Numeric)  Arm (Numeric)  Wingspan (Numeric)  \
# ...

# %%
SlowWR = WR1[(WR1['40 Yard Dash'] >= 4.7)]
SlowWR.head()
# Out:
#                 Name Position        School   Height  Weight Hand Size  \
# 5         Josh Kelly       WR    Texas Tech  6-0 5/8   186.0      10.5
# 1181        T.J. Moe       WR      Missouri     5-11   204.0       NaN
# 1338      Chris Boyd       WR    Vanderbilt      6-4   206.0       NaN
# 1367     Kain Colter       WR  Northwestern     5-10   198.0       NaN
# 1754  Devin Funchess       WR      Michigan      6-4   232.0       NaN
#
#      Arm Length Wingspan 40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 5        30.875      NaN          4.7          NaN  ...               55.0
# 1181        NaN      NaN         4.74         26.0  ...                NaN
# 1338        NaN      NaN         4.73         12.0  ...                NaN
# 1367        NaN      NaN         4.71          NaN  ...                NaN
# 1754        NaN      NaN          4.7         17.0  ...                NaN
#
#       Height (Numeric)  Hand (Numeric)  Arm (Numeric)  Wingspan (Numeric)  \
# ...

# %%
#Drafted rounds by 40 yard dash time

FastGroupRd = FastWR.groupby('Round')['40 Yard Dash'].count()
FastGroupRd
# Out:
# Round
# 0.0    12
# 1.0    16
# 2.0    16
# 3.0    21
# 4.0    11
# 5.0     5
# 6.0     9
# 7.0     1
# Name: 40 Yard Dash, dtype: int64

# %% [markdown]
# 79 Wide Receivers drafted who ran a 40 yard dash between 4.2 and 4.4

# %%
MediumGroupRd = MediumWR.groupby('Round')['40 Yard Dash'].count()
MediumGroupRd
# Out:
# Round
# 0.0    129
# 1.0     10
# 2.0     19
# 3.0     19
# 4.0     24
# 5.0     14
# 6.0     22
# 7.0     13
# Name: 40 Yard Dash, dtype: int64

# %% [markdown]
#  Wide Receivers drafted who ran a 40 yard dash between 4.5 and 4.6

# %%
SlowGroupRd = SlowWR.groupby('Round')['40 Yard Dash'].count()
SlowGroupRd
# Out:
# Round
# 0.0    13
# 2.0     1
# 5.0     1
# 7.0     2
# Name: 40 Yard Dash, dtype: int64

# %% [markdown]
# 4 Wide Receivers have been drafted who ran a 40 yard dash of 4.7 or higher

# %%
print('The slowest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:', WR1['40 Yard Dash'].max())
print('The fastest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:',WR1['40 Yard Dash'].min())
WR1mean = WR1['40 Yard Dash'].mean()
print('The average 40 yard dash ran by a receiver at the NFL Combine since 2010 (exlcuding 2014) was:',round(WR1mean,2))
WR1std = WR1['40 Yard Dash'].std()
print('The standard deviation of the 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:',round(WR1std,4))
# Out:
# The slowest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 4.85
# The fastest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 4.22
# The average 40 yard dash ran by a receiver at the NFL Combine since 2010 (exlcuding 2014) was: 4.5
# The standard deviation of the 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 0.0995

# %%
WR1 = WR1.reset_index(drop=True)
plt.title('Wide Receiver 40 Yard Dash by Frequency')
plt.xlabel('40 Yard Dash')
plt.ylabel('Frequency')
sns.histplot(data=WR1, x='40 Yard Dash', bins = 3, color='orange')
plt.show()

# %% [markdown]
# 75% of Wide Recievers who participated in the NFL combine ran a 40 yard dash between 4.4 and 4.6

# %%
plt.title('Box Plot: Wide Receiver 40 Yard Dash variance')
plt.xlabel('40 Yard Dash')

sns.boxplot(data=WR1, x='40 Yard Dash')
plt.show()

# %% [markdown]
# There are three outliers in the dataset which depicts that players who ran a 40 yard dash slower than 4.8 were considered outliers. The median was slightly greater than 4.50. The Q3 is 4.57, the Q1 is 4.43.

# %%
sns.lineplot(data=WR1, x='Round', y='40 Yard Dash')
plt.title('Wide Receiver 40 Yard Dash by Round')
plt.xlabel('Round')
plt.ylabel('40 Yard Dash')
plt.show()

# %%
sns.boxplot(data=WR1, x='Round', y='40 Yard Dash', color = 'grey')
plt.title('Wide Receiver 40 Yard Dash by Round')
plt.xlabel('Round')
plt.ylabel('40 Yard Dash')
plt.show()

# %% [markdown]
# 4 Wide Receivers have been drafted who ran a 40 yard dash of 4.7 or higher

# %%
print('The slowest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:', WR1['40 Yard Dash'].max())
print('The fastest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:',WR1['40 Yard Dash'].min())
WR1mean = WR1['40 Yard Dash'].mean()
print('The average 40 yard dash ran by a receiver at the NFL Combine since 2010 (exlcuding 2014) was:',round(WR1mean,2))
WR1std = WR1['40 Yard Dash'].std()
print('The standard deviation of the 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was:',round(WR1std,4))
# Out:
# The slowest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 4.85
# The fastest 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 4.22
# The average 40 yard dash ran by a receiver at the NFL Combine since 2010 (exlcuding 2014) was: 4.5
# The standard deviation of the 40 yard dash ran by a receiver at the NFL Combine since 2010 (excluding 2014) was: 0.0995

# %% [markdown]
# BELOW IS A WORK IN PROGRESS

# %% [markdown]
# ##Running Back dataset from Dataset 3

# %%
#Create a dataframe that is specific to Running Backs
RB1 = df3[(df3['Position'] == 'RB') ]
RB1.head()
# Out:
#                   Name Position      School    Height  Weight Hand Size  \
# 25       Kaleb Johnson       RB        Iowa      6-1    224.0     9.625
# 28  Ulysses Bentley IV       RB    Ole Miss   5-9 7/8   201.0     8.625
# 33         Corey Kiner       RB  Cincinnati   5-8 5/8   208.0      7.75
# 52       Kyle Monangai       RB     Rutgers   5-8 2/8   211.0         9
# 68     Damien Martinez       RB       Miami  5-11 5/8   217.0       9.5
#
#    Arm Length Wingspan 40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 25         33     78.5         4.57          NaN  ...               64.0
# 28         29   71.125         4.62          NaN  ...               65.0
# 33       30.5     75.5         4.57         19.0  ...               66.0
# 52      28.75       71         4.60          NaN  ...               69.0
# 68       30.5    75.25         4.51          NaN  ...               72.0
#
#     Height (Numeric)  Hand (Numeric)  Arm (Numeric)  Wingspan (Numeric)  \
# ...

# %%
#Just run this piece of code once: RB1['40 Yard Dash'] = pd.to_numeric(RB1['40 Yard Dash'], errors='coerce')
FastRB = RB1[(RB1['40 Yard Dash'] >= 4.2) & (RB1['40 Yard Dash'] <= 4.4)]
FastRB.head()
# Out:
# <ipython-input-54-82d1790e3f62>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RB1['40 Yard Dash'] = pd.to_numeric(RB1['40 Yard Dash'], errors='coerce')
#                Name Position         School   Height  Weight Hand Size  \
# 96   Brashard Smith       RB            SMU  5-9 7/8   194.0      8.75
# 97        RJ Harvey       RB            UCF      5-8   205.0         9
# 141  Bhayshul Tuten       RB  Virginia Tech  5-9 1/4   200.0         9
# 163     Jaydon Blue       RB          Texas      5-9   196.0      8.25
# 22      Jahvid Best       RB     California     5-10   199.0       NaN
#
#     Arm Length Wingspan  40 Yard Dash  Bench Press  ...  Athleticism Score  \
# ...

# %%
MediumRB = RB1[(RB1['40 Yard Dash'] >= 4.5) & (RB1['40 Yard Dash'] <= 4.6)]
MediumRB.head()
# Out:
#                Name Position      School    Height  Weight Hand Size  \
# 25    Kaleb Johnson       RB        Iowa      6-1    224.0     9.625
# 33      Corey Kiner       RB  Cincinnati   5-8 5/8   208.0      7.75
# 52    Kyle Monangai       RB     Rutgers   5-8 2/8   211.0         9
# 68  Damien Martinez       RB       Miami  5-11 5/8   217.0       9.5
# 69      Woody Marks       RB         USC  5-10 1/8   207.0         9
#
#    Arm Length Wingspan  40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 25         33     78.5          4.57          NaN  ...               64.0
# 33       30.5     75.5          4.57         19.0  ...               66.0
# 52      28.75       71          4.60          NaN  ...               69.0
# 68       30.5    75.25          4.51          NaN  ...               72.0
# 69     29.125   71.875          4.54         18.0  ...               72.0
#
#     Height (Numeric)  Hand (Numeric)  Arm (Numeric)  Wingspan (Numeric)  \
# ...

# %%
SlowRB = RB1[(RB1['40 Yard Dash'] >= 4.7)]
SlowRB.head()
# Out:
#                   Name Position          School Height  Weight Hand Size  \
# 24   LeGarrette Blount       RB          Oregon    6-0   241.0       NaN
# 336        Matt Asiata       RB            Utah   5-11   229.0       NaN
# 384          John Clay       RB       Wisconsin    6-0   230.0       NaN
# 405      Shaun Draughn       RB  North Carolina   5-11   213.0       NaN
# 951         Marc Tyler       RB             USC   5-11   219.0       NaN
#
#     Arm Length Wingspan  40 Yard Dash  Bench Press  ...  Athleticism Score  \
# 24         NaN      NaN          4.70         18.0  ...                NaN
# 336        NaN      NaN          4.77         22.0  ...                NaN
# 384        NaN      NaN          4.83          NaN  ...                NaN
# 405        NaN      NaN          4.73         21.0  ...                NaN
# 951        NaN      NaN          4.70         19.0  ...                NaN
#
#      Height (Numeric)  Hand (Numeric)  Arm (Numeric)  Wingspan (Numeric)  \
# ...
